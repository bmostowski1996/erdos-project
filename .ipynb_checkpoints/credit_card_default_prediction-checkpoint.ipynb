# %% [markdown]
# # Task for Today
#
# ***
#
# ## Credit Card Default Prediction
#
# Given *data about credit card clients*, let's try to predict whether a given client will **default** or not.
#
# We will use logistic regression, support vector machine, and neural network models to make our predictions.

# %% [markdown]
# # Getting Started

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
data = pd.read_excel("default of credit card clients.xls", header=1)

# %%
data.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
#  13  BILL_AMT2                   30000 non-null  int64
#  14  BILL_AMT3                   30000 non-null  int64
#  15  BILL_AMT4                   30000 non-null  int64
#  16  BILL_AMT5                   30000 non-null  int64
#  17  BILL_AMT6                   30000 non-null  int64
#  18  PAY_AMT1                    30000 non-null  int64
#  19  PAY_AMT2                    30000 non-null  int64
#  20  PAY_AMT3                    30000 non-null  int64
#  21  PAY_AMT4                    30000 non-null  int64
#  22  PAY_AMT5                    30000 non-null  int64
#  23  PAY_AMT6                    30000 non-null  int64
#  24  default payment next month  30000 non-null  int64
# dtypes: int64(25)
# memory usage: 5.7 MB

# %% [markdown]
# # Visualization

# %%
corr = data.corr()
plt.figure(figsize=(16, 13))
sns.heatmap(corr, annot=True, vmin=-1.0, cmap='mako')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # Preprocessing

# %%
{'EDUCATION': 'EDU'}.items()
# Out:
# dict_items([('EDUCATION', 'EDU')])

# %%
def onehot_encode(df, column_dict):
    df = df.copy()
    for column, prefix in column_dict.items():
        dummies = pd.get_dummies(df[column], prefix=prefix)
        df = pd.concat([df, dummies], axis=1)
        df = df.drop(column, axis=1)
    return df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print(column_dict)
#       2 def onehot_encode(df, column_dict):
#       3     df = df.copy()
#
# NameError: name 'column_dict' is not defined

# %%
def preprocess_inputs(df):
    df = df.copy()
    
    # Drop ID
    df = df.drop('ID', axis=1)
    
    df = onehot_encode(
        df,
        {
            'EDUCATION': 'EDU',
            'MARRIAGE': 'MAR'
        }
    )
    
    # Split df into X and y
    #y = df['default.payment.next.month'].copy()
    y = df['default payment next month'].copy()
    X = df.drop('default payment next month', axis=1).copy()
    #X = df.drop('default.payment.next.month', axis=1).copy()
    
    # Scale X with a standard scaler
    scaler = StandardScaler()
    X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
    
    return X, y

# %%
X, y = preprocess_inputs(data)

# %%
X
# Out:
#        LIMIT_BAL       SEX       AGE     PAY_0     PAY_2     PAY_3     PAY_4  \
# 0      -1.136720  0.810161 -1.246020  1.794564  1.782348 -0.696663 -0.666599
# 1      -0.365981  0.810161 -1.029047 -0.874991  1.782348  0.138865  0.188746
# 2      -0.597202  0.810161 -0.161156  0.014861  0.111736  0.138865  0.188746
# 3      -0.905498  0.810161  0.164303  0.014861  0.111736  0.138865  0.188746
# 4      -0.905498 -1.234323  2.334029 -0.874991  0.111736 -0.696663  0.188746
# ...          ...       ...       ...       ...       ...       ...       ...
# 29995   0.404759 -1.234323  0.381275  0.014861  0.111736  0.138865  0.188746
# 29996  -0.134759 -1.234323  0.815221 -0.874991 -0.723570 -0.696663 -0.666599
# 29997  -1.059646 -1.234323  0.164303  3.574267  2.617654  1.809921 -0.666599
# 29998  -0.674276 -1.234323  0.598248  0.904712 -0.723570  0.138865  0.188746
# 29999  -0.905498 -1.234323  1.140680  0.014861  0.111736  0.138865  0.188746
#
#           PAY_5     PAY_6  BILL_AMT1  ...     EDU_1     EDU_2     EDU_3  \
# 0     -1.530046 -1.486041  -0.642501  ... -0.738375  1.066900 -0.442752
# 1      0.234917  1.992316  -0.659219  ... -0.738375  1.066900 -0.442752
# 2      0.234917  0.253137  -0.298560  ... -0.738375  1.066900 -0.442752
# 3      0.234917  0.253137  -0.057491  ... -0.738375  1.066900 -0.442752
# 4      0.234917  0.253137  -0.578618  ... -0.738375  1.066900 -0.442752
# ...         ...       ...        ...  ...       ...       ...       ...
# 29995  0.234917  0.253137   1.870379  ... -0.738375 -0.937295  2.258602
# 29996  0.234917  0.253137  -0.672786  ... -0.738375 -0.937295  2.258602
# 29997  0.234917  0.253137  -0.647227  ... -0.738375  1.066900 -0.442752
# 29998  0.234917 -0.616452  -0.717982  ... -0.738375 -0.937295  2.258602
# 29999  0.234917  0.253137  -0.044739  ... -0.738375  1.066900 -0.442752
#
#           EDU_4     EDU_5     EDU_6     MAR_0     MAR_1     MAR_2     MAR_3
# 0     -0.064163 -0.097063 -0.041266 -0.042465  1.093780 -1.066471 -0.104326
# 1     -0.064163 -0.097063 -0.041266 -0.042465 -0.914261  0.937672 -0.104326
# 2     -0.064163 -0.097063 -0.041266 -0.042465 -0.914261  0.937672 -0.104326
# 3     -0.064163 -0.097063 -0.041266 -0.042465  1.093780 -1.066471 -0.104326
# 4     -0.064163 -0.097063 -0.041266 -0.042465  1.093780 -1.066471 -0.104326
# ...         ...       ...       ...       ...       ...       ...       ...
# 29995 -0.064163 -0.097063 -0.041266 -0.042465  1.093780 -1.066471 -0.104326
# 29996 -0.064163 -0.097063 -0.041266 -0.042465 -0.914261  0.937672 -0.104326
# 29997 -0.064163 -0.097063 -0.041266 -0.042465 -0.914261  0.937672 -0.104326
# 29998 -0.064163 -0.097063 -0.041266 -0.042465  1.093780 -1.066471 -0.104326
# 29999 -0.064163 -0.097063 -0.041266 -0.042465  1.093780 -1.066471 -0.104326
#
# [30000 rows x 32 columns]

# %%
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 29995    0
# 29996    0
# 29997    1
# 29998    1
# 29999    1
# Name: default payment next month, Length: 30000, dtype: int64

# %%
{column: len(X[column].unique()) for column in X.columns}
# Out:
# {'LIMIT_BAL': 81,
#  'SEX': 2,
#  'AGE': 56,
#  'PAY_0': 11,
#  'PAY_2': 11,
#  'PAY_3': 11,
#  'PAY_4': 11,
#  'PAY_5': 10,
#  'PAY_6': 10,
#  'BILL_AMT1': 22723,
#  'BILL_AMT2': 22346,
#  'BILL_AMT3': 22026,
#  'BILL_AMT4': 21548,
#  'BILL_AMT5': 21010,
#  'BILL_AMT6': 20604,
#  'PAY_AMT1': 7943,
#  'PAY_AMT2': 7899,
#  'PAY_AMT3': 7518,
#  'PAY_AMT4': 6937,
#  'PAY_AMT5': 6897,
#  'PAY_AMT6': 6939,
#  'EDU_0': 2,
#  'EDU_1': 2,
#  'EDU_2': 2,
#  'EDU_3': 2,
#  'EDU_4': 2,
#  'EDU_5': 2,
#  'EDU_6': 2,
#  'MAR_0': 2,
#  'MAR_1': 2,
#  'MAR_2': 2,
#  'MAR_3': 2}

# %% [markdown]
# # Training

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=123)

# %%
# Create and fit the logistic regression model
clf_logistic = LogisticRegression(solver='lbfgs').fit(X_train, np.ravel(y_train))

# Print the models coefficients
print(clf_logistic.coef_)
# Out:
# [[-0.07391066 -0.06560366  0.04594474  0.62643679  0.09439256  0.09760826
#   -0.00669273  0.04729133  0.04005348 -0.44708577  0.16862924  0.08105853
#    0.08402481  0.08488268 -0.05676865 -0.21457128 -0.25493799 -0.1067462
#   -0.06520911 -0.0171216  -0.04046545 -0.13131492  0.03887616 -0.00378487
#    0.00351637 -0.0587529  -0.11357256 -0.01162902 -0.02901006  0.04457416
#   -0.04294613  0.00446232]]

# %%
# Create predictions and store them in a variable
preds = clf_logistic.predict_proba(X_test)
print(preds)
# Print the accuracy score the model
print(clf_logistic.score(X_test, y_test))

# Plot the ROC curve of the probabilities of default
prob_default = preds[:, 1]
fallout, sensitivity, thresholds = metrics.roc_curve(y_test, prob_default)
plt.plot(fallout, sensitivity, color = 'darkorange')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.show()

# Compute the AUC and store it in a variable
auc = metrics.roc_auc_score(y_test, prob_default)
auc
# Out:
# [[0.88733199 0.11266801]
#  [0.76115198 0.23884802]
#  [0.4939395  0.5060605 ]
#  ...
#  [0.50378583 0.49621417]
#  [0.87468848 0.12531152]
#  [0.85198579 0.14801421]]
# 0.8151666666666667
# 0.7336868409088534

# %% [markdown]
# # Neural Networks

# %%
import keras
import tensorflow as tf

#This stuff should help simpify writing later on down the line
from keras import models
from keras import layers
from keras import optimizers
from keras import losses
from keras import metrics
from keras.utils.np_utils import to_categorical

# %%
#First, create the model
model = models.Sequential()
model.add(layers.Dense(64, activation = 'relu', input_shape=(32,)))
model.add(layers.Dense(64, activation = 'relu'))
model.add(layers.Dense(1, activation = 'sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                2112
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 6,337
# Trainable params: 6,337
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Now, compile the model
model.compile(optimizer='rmsprop', 
                 loss='binary_crossentropy',
                 metrics=['accuracy'])

# %%
#We are ready to train the model!
n_epochs = 100
batch_size = 512
X_train, X_test, y_train, y_test
history = model.fit(X_train, y_train,
                       epochs = n_epochs,
                       batch_size = batch_size,
                       validation_data = (X_test, y_test))
# Out:
# Epoch 1/100
# 47/47 [==============================] - 1s 5ms/step - loss: 0.3898 - accuracy: 0.8366 - val_loss: 0.4426 - val_accuracy: 0.8108
# Epoch 2/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3869 - accuracy: 0.8380 - val_loss: 0.4440 - val_accuracy: 0.8130
# Epoch 3/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3867 - accuracy: 0.8370 - val_loss: 0.4459 - val_accuracy: 0.8098
# Epoch 4/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3863 - accuracy: 0.8368 - val_loss: 0.4503 - val_accuracy: 0.8067
# Epoch 5/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3861 - accuracy: 0.8374 - val_loss: 0.4481 - val_accuracy: 0.8062
# Epoch 6/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3858 - accuracy: 0.8382 - val_loss: 0.4486 - val_accuracy: 0.8053
# Epoch 7/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3856 - accuracy: 0.8353 - val_loss: 0.4479 - val_accuracy: 0.8047
# Epoch 8/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3849 - accuracy: 0.8378 - val_loss: 0.4460 - val_accuracy: 0.8092
# Epoch 9/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3850 - accuracy: 0.8373 - val_loss: 0.4470 - val_accuracy: 0.8087
# Epoch 10/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3848 - accuracy: 0.8372 - val_loss: 0.4464 - val_accuracy: 0.8108
# Epoch 11/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3852 - accuracy: 0.8379 - val_loss: 0.4456 - val_accuracy: 0.8117
# Epoch 12/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3841 - accuracy: 0.8391 - val_loss: 0.4472 - val_accuracy: 0.8163
# Epoch 13/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3839 - accuracy: 0.8380 - val_loss: 0.4482 - val_accuracy: 0.8147
# Epoch 14/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3830 - accuracy: 0.8371 - val_loss: 0.4465 - val_accuracy: 0.8103
# Epoch 15/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3838 - accuracy: 0.8388 - val_loss: 0.4488 - val_accuracy: 0.8097
# Epoch 16/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3824 - accuracy: 0.8387 - val_loss: 0.4530 - val_accuracy: 0.8032
# Epoch 17/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3828 - accuracy: 0.8385 - val_loss: 0.4466 - val_accuracy: 0.8105
# Epoch 18/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3820 - accuracy: 0.8395 - val_loss: 0.4506 - val_accuracy: 0.8098
# Epoch 19/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3821 - accuracy: 0.8387 - val_loss: 0.4491 - val_accuracy: 0.8137
# Epoch 20/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3818 - accuracy: 0.8393 - val_loss: 0.4511 - val_accuracy: 0.8135
# Epoch 21/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3821 - accuracy: 0.8378 - val_loss: 0.4487 - val_accuracy: 0.8122
# Epoch 22/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3805 - accuracy: 0.8405 - val_loss: 0.4490 - val_accuracy: 0.8103
# Epoch 23/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3806 - accuracy: 0.8399 - val_loss: 0.4495 - val_accuracy: 0.8105
# Epoch 24/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3800 - accuracy: 0.8384 - val_loss: 0.4476 - val_accuracy: 0.8115
# Epoch 25/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3802 - accuracy: 0.8396 - val_loss: 0.4478 - val_accuracy: 0.8092
# Epoch 26/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3800 - accuracy: 0.8395 - val_loss: 0.4514 - val_accuracy: 0.8075
# Epoch 27/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3793 - accuracy: 0.8410 - val_loss: 0.4503 - val_accuracy: 0.8143
# Epoch 28/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3794 - accuracy: 0.8386 - val_loss: 0.4515 - val_accuracy: 0.8062
# Epoch 29/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3794 - accuracy: 0.8392 - val_loss: 0.4487 - val_accuracy: 0.8097
# Epoch 30/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3801 - accuracy: 0.8388 - val_loss: 0.4516 - val_accuracy: 0.8077
# Epoch 31/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3782 - accuracy: 0.8417 - val_loss: 0.4495 - val_accuracy: 0.8087
# Epoch 32/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3788 - accuracy: 0.8399 - val_loss: 0.4484 - val_accuracy: 0.8133
# Epoch 33/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3777 - accuracy: 0.8415 - val_loss: 0.4512 - val_accuracy: 0.8142
# Epoch 34/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3773 - accuracy: 0.8420 - val_loss: 0.4502 - val_accuracy: 0.8053
# Epoch 35/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3773 - accuracy: 0.8425 - val_loss: 0.4516 - val_accuracy: 0.8067
# Epoch 36/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3783 - accuracy: 0.8420 - val_loss: 0.4493 - val_accuracy: 0.8107
# Epoch 37/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3772 - accuracy: 0.8409 - val_loss: 0.4562 - val_accuracy: 0.8028
# Epoch 38/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3774 - accuracy: 0.8396 - val_loss: 0.4619 - val_accuracy: 0.7990
# Epoch 39/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3752 - accuracy: 0.8417 - val_loss: 0.4536 - val_accuracy: 0.8080
# Epoch 40/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3762 - accuracy: 0.8415 - val_loss: 0.4538 - val_accuracy: 0.8097
# Epoch 41/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3758 - accuracy: 0.8425 - val_loss: 0.4517 - val_accuracy: 0.8087
# Epoch 42/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3753 - accuracy: 0.8425 - val_loss: 0.4522 - val_accuracy: 0.8077
# Epoch 43/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3753 - accuracy: 0.8424 - val_loss: 0.4519 - val_accuracy: 0.8073
# Epoch 44/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3748 - accuracy: 0.8418 - val_loss: 0.4555 - val_accuracy: 0.8062
# Epoch 45/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3758 - accuracy: 0.8405 - val_loss: 0.4580 - val_accuracy: 0.8027
# Epoch 46/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3747 - accuracy: 0.8419 - val_loss: 0.4630 - val_accuracy: 0.8017
# Epoch 47/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3749 - accuracy: 0.8425 - val_loss: 0.4549 - val_accuracy: 0.8052
# Epoch 48/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3735 - accuracy: 0.8414 - val_loss: 0.4540 - val_accuracy: 0.8088
# Epoch 49/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3735 - accuracy: 0.8420 - val_loss: 0.4643 - val_accuracy: 0.8012
# Epoch 50/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3729 - accuracy: 0.8437 - val_loss: 0.4616 - val_accuracy: 0.7995
# Epoch 51/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3733 - accuracy: 0.8435 - val_loss: 0.4565 - val_accuracy: 0.8065
# Epoch 52/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3731 - accuracy: 0.8428 - val_loss: 0.4596 - val_accuracy: 0.8045
# Epoch 53/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3725 - accuracy: 0.8424 - val_loss: 0.4572 - val_accuracy: 0.8048
# Epoch 54/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3724 - accuracy: 0.8433 - val_loss: 0.4713 - val_accuracy: 0.7922
# Epoch 55/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3721 - accuracy: 0.8442 - val_loss: 0.4544 - val_accuracy: 0.8083
# Epoch 56/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3723 - accuracy: 0.8432 - val_loss: 0.4608 - val_accuracy: 0.8022
# Epoch 57/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3720 - accuracy: 0.8428 - val_loss: 0.4547 - val_accuracy: 0.8092
# Epoch 58/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3711 - accuracy: 0.8430 - val_loss: 0.4558 - val_accuracy: 0.8053
# Epoch 59/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3718 - accuracy: 0.8422 - val_loss: 0.4631 - val_accuracy: 0.8015
# Epoch 60/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3701 - accuracy: 0.8442 - val_loss: 0.4613 - val_accuracy: 0.8140
# Epoch 61/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3717 - accuracy: 0.8442 - val_loss: 0.4618 - val_accuracy: 0.8067
# Epoch 62/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3694 - accuracy: 0.8441 - val_loss: 0.4586 - val_accuracy: 0.8030
# Epoch 63/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3698 - accuracy: 0.8437 - val_loss: 0.4570 - val_accuracy: 0.8048
# Epoch 64/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3694 - accuracy: 0.8450 - val_loss: 0.4607 - val_accuracy: 0.8038
# Epoch 65/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3700 - accuracy: 0.8443 - val_loss: 0.4702 - val_accuracy: 0.7970
# Epoch 66/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3681 - accuracy: 0.8440 - val_loss: 0.4593 - val_accuracy: 0.8050
# Epoch 67/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3693 - accuracy: 0.8432 - val_loss: 0.4581 - val_accuracy: 0.8062
# Epoch 68/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3686 - accuracy: 0.8432 - val_loss: 0.4621 - val_accuracy: 0.8062
# Epoch 69/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3684 - accuracy: 0.8444 - val_loss: 0.4607 - val_accuracy: 0.8047
# Epoch 70/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3682 - accuracy: 0.8448 - val_loss: 0.4632 - val_accuracy: 0.8072
# Epoch 71/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3687 - accuracy: 0.8455 - val_loss: 0.4645 - val_accuracy: 0.8037
# Epoch 72/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3681 - accuracy: 0.8450 - val_loss: 0.4604 - val_accuracy: 0.8043
# Epoch 73/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3678 - accuracy: 0.8450 - val_loss: 0.4651 - val_accuracy: 0.8033
# Epoch 74/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3678 - accuracy: 0.8445 - val_loss: 0.4639 - val_accuracy: 0.8013
# Epoch 75/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3673 - accuracy: 0.8450 - val_loss: 0.4665 - val_accuracy: 0.8088
# Epoch 76/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3677 - accuracy: 0.8461 - val_loss: 0.4631 - val_accuracy: 0.8072
# Epoch 77/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3666 - accuracy: 0.8463 - val_loss: 0.4811 - val_accuracy: 0.7912
# Epoch 78/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3674 - accuracy: 0.8445 - val_loss: 0.4618 - val_accuracy: 0.8058
# Epoch 79/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3665 - accuracy: 0.8453 - val_loss: 0.4668 - val_accuracy: 0.8080
# Epoch 80/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3671 - accuracy: 0.8455 - val_loss: 0.4664 - val_accuracy: 0.8015
# Epoch 81/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3653 - accuracy: 0.8461 - val_loss: 0.4709 - val_accuracy: 0.8088
# Epoch 82/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3669 - accuracy: 0.8467 - val_loss: 0.4725 - val_accuracy: 0.7955
# Epoch 83/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3644 - accuracy: 0.8461 - val_loss: 0.4645 - val_accuracy: 0.8053
# Epoch 84/100
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3646 - accuracy: 0.8445 - val_loss: 0.4784 - val_accuracy: 0.7978
# Epoch 85/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3647 - accuracy: 0.8467 - val_loss: 0.4627 - val_accuracy: 0.8052
# Epoch 86/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3649 - accuracy: 0.8469 - val_loss: 0.4686 - val_accuracy: 0.8017
# Epoch 87/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3639 - accuracy: 0.8466 - val_loss: 0.4632 - val_accuracy: 0.8038
# Epoch 88/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3640 - accuracy: 0.8472 - val_loss: 0.4653 - val_accuracy: 0.8015
# Epoch 89/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3635 - accuracy: 0.8472 - val_loss: 0.4667 - val_accuracy: 0.8007
# Epoch 90/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3636 - accuracy: 0.8462 - val_loss: 0.4672 - val_accuracy: 0.8007
# Epoch 91/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3629 - accuracy: 0.8460 - val_loss: 0.4713 - val_accuracy: 0.8020
# Epoch 92/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3633 - accuracy: 0.8464 - val_loss: 0.4822 - val_accuracy: 0.7950
# Epoch 93/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3631 - accuracy: 0.8468 - val_loss: 0.4703 - val_accuracy: 0.7978
# Epoch 94/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3619 - accuracy: 0.8481 - val_loss: 0.4668 - val_accuracy: 0.8067
# Epoch 95/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3627 - accuracy: 0.8473 - val_loss: 0.4686 - val_accuracy: 0.8020
# Epoch 96/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3626 - accuracy: 0.8465 - val_loss: 0.4650 - val_accuracy: 0.8063
# Epoch 97/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3633 - accuracy: 0.8463 - val_loss: 0.4672 - val_accuracy: 0.8030
# Epoch 98/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3616 - accuracy: 0.8482 - val_loss: 0.4714 - val_accuracy: 0.8052
# Epoch 99/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3632 - accuracy: 0.8466 - val_loss: 0.4784 - val_accuracy: 0.7945
# Epoch 100/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3614 - accuracy: 0.8459 - val_loss: 0.4733 - val_accuracy: 0.7965

# %%
# Training and Testing K Neighbor Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=123)
knn = KNeighborsClassifier() 
knn.fit(X_train, y_train)
print(knn.score(X_test, y_test))
# Out:
# 0.7936666666666666
